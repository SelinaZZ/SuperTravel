# %%
import datetime
import numpy as np
import pandas as pd
import pandas_datareader.data as web

# %%
data = pd.read_csv("tour.csv")

# %%
data
# Out:
#         id                                               name  review_count  \
# 0        1                     The Metropolitan Museum of Art          2611
# 1        2                                           Spyscape           119
# 2        3                 American Museum of Natural History          1913
# 3        4                           The Museum of Modern Art          1890
# 4        5                         Museum of the Moving Image           508
# 5        6                    Museum of the American Gangster           104
# 6        7                                    Brooklyn Museum           562
# 7        8                     Whitney Museum of American Art           397
# 8        9                            New York Transit Museum           369
# 9       10                                  Guggenheim Museum           929
# 10      11                                      Museum of Sex           997
# ...

# %%
data['categories'].unique()
# Out:
# array(['Galleries', 'Museums', 'Tourist Attraction', 'Shopping Center',
#        'Amusement'], dtype=object)

# %%
data = data.sort_values(by=['rate'], ascending=False)

# %%
#Museum
list_Museum = []
for i in range(len(data['name'])):
    if data['categories'][i]== 'Museums' and data['rate'][i] == 5:
        list_Museum.append(data['name'][i])
new_list = list_Museum[0:10]
print(new_list)
# Out:
# ['Mmuseumm', 'Houdini Museum', 'A Night at the Museum', 'Brooklyn Historical Society DUMBO', 'Louis Armstrong House Museum', 'Smithsonian Institution', 'Chelsea Galleries', 'Museum Hack', 'Waterfront Museum', 'The Bedford Stuyvesant Museum of African Art']

# %%
# list_Art_Museum = []
# for i in range(len(data['name'])):
#     if data['subcate'][i]== 'Art Museums':
#         list_Art_Museum.append(data['name'][i])
# new_list_2 = list_Art_Museum[0:9]
# print(new_list_2)

# %%
# Amusement
list_Amusement = []
for i in range(len(data['name'])):
    if data['categories'][i]== 'Amusement':
        list_Amusement.append(data['name'][i])
new_list_3 = list_Amusement[0:10]
print(new_list_3)
# Out:
# ['Adventurers Family Entertainment Center', 'Victorian Gardens Amusement Park', 'National Geographic Encounter: Ocean Odyssey', "Deno's Wonder Wheel Amusement & Kiddie Park", 'Party Jungle', 'Coney Island Beach and Boardwalk', 'Luna Park', 'Carousel For All Children', 'Riverside Park Pier 1', 'Kids N Action']

# %%
# Galleries
list_Galleries = []
for i in range(len(data['name'])):
    if data['categories'][i]== 'Galleries':
        list_Galleries.append(data['name'][i])
new_list_4 = list_Galleries[0:10]
print(new_list_4)
# Out:
# ['David Zwirner', 'Eli Klein Gallery', 'The THNK1994 Museum', 'The Pace Gallery', 'Pop International Galleries', 'Krause Gallery', 'Barsky Gallery', 'Gagosian', 'Floating Mountain', 'Deitch Projects']

# %%
# Shopping Center
list_Shopping_Center = []
for i in range(len(data['name'])):
    if data['categories'][i]== 'Shopping Center':
        list_Shopping_Center.append(data['name'][i])
new_list_5 = list_Shopping_Center[0:10]
print(new_list_5)
# Out:
# ['Westfield World Trade Center', 'Brookfield Place', 'SoHo', 'Fulton Street Mall', 'Gateway Center', 'The Atrium Shops & Cafes', 'The Mini Mall', 'Broadway Plaza Outparcel', 'Throgs Neck Shopping Center', 'Phoenix Mall Incorporated']

# %%
# Tourist Attraction
list_Tourist_Attraction = []
for i in range(len(data['name'])):
    if data['categories'][i]== 'Tourist Attraction':
        list_Tourist_Attraction.append(data['name'][i])
new_list_6 = list_Tourist_Attraction[0:10]
print(new_list_6)
# Out:
# ['Oculus', 'Top of the Rock', 'The High Line', 'Spyscape', 'The Unisphere', 'Brooklyn Bridge', 'Whispering Gallery', 'Strawberry Fields', 'Grand Central Terminal', 'Statue of Liberty']

# %%
# Museum and Amusement
list_Museum_Amusement = list_Museum[0:5] + list_Amusement[0:5]
list_Museum_Amusement
# Out:
# ['Mmuseumm',
#  'Houdini Museum',
#  'A Night at the Museum',
#  'Brooklyn Historical Society DUMBO',
#  'Louis Armstrong House Museum',
#  'Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle']

# %%
# Museum and Shopping Center
list_Museum_ShCen = list_Museum[0:5] + list_Shopping_Center[0:5]
list_Museum_ShCen
# Out:
# ['Mmuseumm',
#  'Houdini Museum',
#  'A Night at the Museum',
#  'Brooklyn Historical Society DUMBO',
#  'Louis Armstrong House Museum',
#  'Westfield World Trade Center',
#  'Brookfield Place',
#  'SoHo',
#  'Fulton Street Mall',
#  'Gateway Center']

# %%
# Museum and Amusement
list_Museum_Amusement = list_Museum[0:5] + list_Amusement[0:5]
list_Museum_Amusement
# Out:
# ['Mmuseumm',
#  'Houdini Museum',
#  'A Night at the Museum',
#  'Brooklyn Historical Society DUMBO',
#  'Louis Armstrong House Museum',
#  'Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle']

# %%
# Museum and Tourist Attraction
list_Museum_TA = list_Museum[0:5] + list_Tourist_Attraction[0:5]
list_Museum_TA
# Out:
# ['Mmuseumm',
#  'Houdini Museum',
#  'A Night at the Museum',
#  'Brooklyn Historical Society DUMBO',
#  'Louis Armstrong House Museum',
#  'Oculus',
#  'Top of the Rock',
#  'The High Line',
#  'Spyscape',
#  'The Unisphere']

# %%
# Amusement and Shopping Center
list_Amusement_ShCen = list_Amusement[0:5] + list_Shopping_Center[0:5]
list_Amusement_ShCen
# Out:
# ['Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle',
#  'Westfield World Trade Center',
#  'Brookfield Place',
#  'SoHo',
#  'Fulton Street Mall',
#  'Gateway Center']

# %%
# Amusement and Galleries
list_Amusement_Galleries = list_Amusement[0:5] + list_Galleries[0:5]
list_Amusement_Galleries
# Out:
# ['Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle',
#  'David Zwirner',
#  'Eli Klein Gallery',
#  'The THNK1994 Museum',
#  'The Pace Gallery',
#  'Pop International Galleries']

# %%
# Amusement and Tourist Attraction
list_Amusement_TA = list_Amusement[0:5] + list_Tourist_Attraction[0:5]
list_Amusement_TA
# Out:
# ['Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle',
#  'Oculus',
#  'Top of the Rock',
#  'The High Line',
#  'Spyscape',
#  'The Unisphere']

# %%
# Galleries and Amusement
list_Galleries_Amusement = list_Galleries[0:5] + list_Amusement[0:5]
list_Galleries_Amusement
# Out:
# ['David Zwirner',
#  'Eli Klein Gallery',
#  'The THNK1994 Museum',
#  'The Pace Gallery',
#  'Pop International Galleries',
#  'Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  "Deno's Wonder Wheel Amusement & Kiddie Park",
#  'Party Jungle']

# %%
# Galleries and Shopping Center
list_Galleries_ShCen = list_Galleries[0:5] + list_Shopping_Center[0:5]
list_Galleries_ShCen
# Out:
# ['David Zwirner',
#  'Eli Klein Gallery',
#  'The THNK1994 Museum',
#  'The Pace Gallery',
#  'Pop International Galleries',
#  'Westfield World Trade Center',
#  'Brookfield Place',
#  'SoHo',
#  'Fulton Street Mall',
#  'Gateway Center']

# %%
# Galleries and Tourist Attraction
list_Galleries_TA = list_Galleries[0:5] + list_Tourist_Attraction[0:5]
list_Galleries_TA
# Out:
# ['David Zwirner',
#  'Eli Klein Gallery',
#  'The THNK1994 Museum',
#  'The Pace Gallery',
#  'Pop International Galleries',
#  'Oculus',
#  'Top of the Rock',
#  'The High Line',
#  'Spyscape',
#  'The Unisphere']

# %%
# Shopping Center and Tourist Attraction
list_ShCen_TA = list_Shopping_Center[0:5] + list_Tourist_Attraction[0:5]
list_ShCen_TA
# Out:
# ['Westfield World Trade Center',
#  'Brookfield Place',
#  'SoHo',
#  'Fulton Street Mall',
#  'Gateway Center',
#  'Oculus',
#  'Top of the Rock',
#  'The High Line',
#  'Spyscape',
#  'The Unisphere']

# %%
# Museum, Amusement and Galleries
list_Museum_Amusement_G = list_Museum[0:3] + list_Amusement[0:3] + list_Galleries[0:4]
list_Museum_Amusement_G
# Out:
# ['Mmuseumm',
#  'Houdini Museum',
#  'A Night at the Museum',
#  'Adventurers Family Entertainment Center',
#  'Victorian Gardens Amusement Park',
#  'National Geographic Encounter: Ocean Odyssey',
#  'David Zwirner',
#  'Eli Klein Gallery',
#  'The THNK1994 Museum',
#  'The Pace Gallery']
